# %%
from bs4 import BeautifulSoup
import os
import json

# %%
save_dir = r'/home/alex/data/wir/'
source_dir = r'raffineurs'
save_dir = os.path.join(save_dir, source_dir)
base_url= 'https://www.lesraffineurs.com/'

# %% [markdown]
# # check links

# %%
len([img for img in os.listdir(save_dir) if '1555' in img])
# Out:
# 3

# %% [markdown]
# # check images

# %%
prods = []
for img in os.listdir(save_dir):
    prods.append(
        img.split('-')[0])
prods = list(set(prods))

# %%
len(prods)
# Out:
# 458

# %%
with open('prods.json', 'r') as fp:
    prodjs = json.load(fp)

# %%
len(prodjs)
# Out:
# 457

# %% [markdown]
# # view images

# %%
import os
import webp

# %%
imgs = os.listdir(save_dir)

# %%
# %matplotlib inline

# %%
from PIL import Image               # to load images
from IPython.display import display # to display images
img_path = os.path.join(save_dir, imgs[21])
pil_im = Image.open(img_path)
display(pil_im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x560 at 0x7FAB85B50BA8>
